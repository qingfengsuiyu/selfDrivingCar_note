# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import numpy as np

# %%
def batches(batch_size,features,labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0,sample_size,batch_size):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i],labels[start_i:end_i]]
        outout_batches.append(batch)
    return outout_batches

# %%
def print_epoch_stats(epoch_i,sess,last_features,last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features:last_features,labels:last_labels})
    
    valid_accuracy = sess.run(
        accuracy,
        feed_dict = {features:valid_features,labels:valid_labels})
    
    print('Epoch:{:<4} - Cost:{:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,current_cost,valid_accuracy))

# %%
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

mnist = input_data.read_data_sets('./',one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input,n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 100
learn_rate = 0.001

train_batches = batches(batch_size, train_features, train_labels)
# Out:
# Extracting ./train-images-idx3-ubyte.gz
# Extracting ./train-labels-idx1-ubyte.gz
# Extracting ./t10k-images-idx3-ubyte.gz
# Extracting ./t10k-labels-idx1-ubyte.gz

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Training cycle
    for epoch_i in range(epochs):
        
        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)
        
            # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)
    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})
print('Test Accuracy:{}'.format(test_accuracy))
# Out:
# Epoch:0    - Cost:9.49     Valid Accuracy: 0.188
# Epoch:1    - Cost:8.65     Valid Accuracy: 0.195
# Epoch:2    - Cost:8.0      Valid Accuracy: 0.202
# Epoch:3    - Cost:7.5      Valid Accuracy: 0.212
# Epoch:4    - Cost:7.09     Valid Accuracy: 0.221
# Epoch:5    - Cost:6.74     Valid Accuracy: 0.237
# Epoch:6    - Cost:6.44     Valid Accuracy: 0.252
# Epoch:7    - Cost:6.16     Valid Accuracy: 0.268
# Epoch:8    - Cost:5.9      Valid Accuracy: 0.287
# Epoch:9    - Cost:5.66     Valid Accuracy: 0.308
# Epoch:10   - Cost:5.43     Valid Accuracy: 0.324
# Epoch:11   - Cost:5.21     Valid Accuracy: 0.338
# Epoch:12   - Cost:5.01     Valid Accuracy: 0.353
# Epoch:13   - Cost:4.82     Valid Accuracy: 0.368
# Epoch:14   - Cost:4.64     Valid Accuracy: 0.383
# Epoch:15   - Cost:4.47     Valid Accuracy: 0.396
# Epoch:16   - Cost:4.32     Valid Accuracy: 0.409
# Epoch:17   - Cost:4.17     Valid Accuracy: 0.422
# Epoch:18   - Cost:4.04     Valid Accuracy: 0.436
# Epoch:19   - Cost:3.91     Valid Accuracy: 0.447
# Epoch:20   - Cost:3.79     Valid Accuracy: 0.456
# Epoch:21   - Cost:3.68     Valid Accuracy: 0.466
# Epoch:22   - Cost:3.58     Valid Accuracy: 0.477
# Epoch:23   - Cost:3.48     Valid Accuracy: 0.484
# Epoch:24   - Cost:3.39     Valid Accuracy: 0.491
# Epoch:25   - Cost:3.3      Valid Accuracy: 0.499
# Epoch:26   - Cost:3.21     Valid Accuracy: 0.506
# Epoch:27   - Cost:3.13     Valid Accuracy: 0.513
# Epoch:28   - Cost:3.06     Valid Accuracy: 0.52
# Epoch:29   - Cost:2.99     Valid Accuracy: 0.528
# Epoch:30   - Cost:2.92     Valid Accuracy: 0.535
# Epoch:31   - Cost:2.86     Valid Accuracy: 0.541
# Epoch:32   - Cost:2.8      Valid Accuracy: 0.545
# Epoch:33   - Cost:2.74     Valid Accuracy: 0.549
# Epoch:34   - Cost:2.68     Valid Accuracy: 0.556
# Epoch:35   - Cost:2.63     Valid Accuracy: 0.561
# Epoch:36   - Cost:2.58     Valid Accuracy: 0.567
# Epoch:37   - Cost:2.53     Valid Accuracy: 0.571
# Epoch:38   - Cost:2.49     Valid Accuracy: 0.576
# Epoch:39   - Cost:2.45     Valid Accuracy: 0.583
# Epoch:40   - Cost:2.41     Valid Accuracy: 0.588
# Epoch:41   - Cost:2.37     Valid Accuracy: 0.592
# Epoch:42   - Cost:2.33     Valid Accuracy: 0.596
# Epoch:43   - Cost:2.29     Valid Accuracy: 0.601
# Epoch:44   - Cost:2.26     Valid Accuracy: 0.605
# Epoch:45   - Cost:2.23     Valid Accuracy: 0.61
# Epoch:46   - Cost:2.2      Valid Accuracy: 0.613
# Epoch:47   - Cost:2.17     Valid Accuracy: 0.617
# Epoch:48   - Cost:2.14     Valid Accuracy: 0.622
# Epoch:49   - Cost:2.11     Valid Accuracy: 0.628
# Epoch:50   - Cost:2.08     Valid Accuracy: 0.632
# Epoch:51   - Cost:2.06     Valid Accuracy: 0.635
# Epoch:52   - Cost:2.03     Valid Accuracy: 0.639
# Epoch:53   - Cost:2.01     Valid Accuracy: 0.643
# Epoch:54   - Cost:1.99     Valid Accuracy: 0.647
# Epoch:55   - Cost:1.96     Valid Accuracy: 0.65
# Epoch:56   - Cost:1.94     Valid Accuracy: 0.652
# Epoch:57   - Cost:1.92     Valid Accuracy: 0.655
# Epoch:58   - Cost:1.9      Valid Accuracy: 0.659
# Epoch:59   - Cost:1.88     Valid Accuracy: 0.662
# Epoch:60   - Cost:1.87     Valid Accuracy: 0.665
# Epoch:61   - Cost:1.85     Valid Accuracy: 0.666
# Epoch:62   - Cost:1.83     Valid Accuracy: 0.67
# Epoch:63   - Cost:1.81     Valid Accuracy: 0.673
# Epoch:64   - Cost:1.8      Valid Accuracy: 0.676
# Epoch:65   - Cost:1.78     Valid Accuracy: 0.679
# Epoch:66   - Cost:1.77     Valid Accuracy: 0.68
# Epoch:67   - Cost:1.75     Valid Accuracy: 0.682
# Epoch:68   - Cost:1.74     Valid Accuracy: 0.685
# Epoch:69   - Cost:1.73     Valid Accuracy: 0.686
# Epoch:70   - Cost:1.71     Valid Accuracy: 0.689
# Epoch:71   - Cost:1.7      Valid Accuracy: 0.691
# Epoch:72   - Cost:1.69     Valid Accuracy: 0.694
# Epoch:73   - Cost:1.67     Valid Accuracy: 0.696
# Epoch:74   - Cost:1.66     Valid Accuracy: 0.698
# Epoch:75   - Cost:1.65     Valid Accuracy: 0.7
# Epoch:76   - Cost:1.64     Valid Accuracy: 0.702
# Epoch:77   - Cost:1.63     Valid Accuracy: 0.703
# Epoch:78   - Cost:1.62     Valid Accuracy: 0.706
# Epoch:79   - Cost:1.61     Valid Accuracy: 0.708
# Epoch:80   - Cost:1.6      Valid Accuracy: 0.709
# Epoch:81   - Cost:1.59     Valid Accuracy: 0.712
# Epoch:82   - Cost:1.58     Valid Accuracy: 0.714
# Epoch:83   - Cost:1.57     Valid Accuracy: 0.716
# Epoch:84   - Cost:1.56     Valid Accuracy: 0.717
# Epoch:85   - Cost:1.55     Valid Accuracy: 0.718
# Epoch:86   - Cost:1.54     Valid Accuracy: 0.719
# Epoch:87   - Cost:1.54     Valid Accuracy: 0.721
# Epoch:88   - Cost:1.53     Valid Accuracy: 0.723
# Epoch:89   - Cost:1.52     Valid Accuracy: 0.725
# Epoch:90   - Cost:1.51     Valid Accuracy: 0.727
# Epoch:91   - Cost:1.5      Valid Accuracy: 0.729
# Epoch:92   - Cost:1.5      Valid Accuracy: 0.731
# Epoch:93   - Cost:1.49     Valid Accuracy: 0.732
# Epoch:94   - Cost:1.48     Valid Accuracy: 0.732
# Epoch:95   - Cost:1.47     Valid Accuracy: 0.734
# Epoch:96   - Cost:1.47     Valid Accuracy: 0.735
# Epoch:97   - Cost:1.46     Valid Accuracy: 0.736
# Epoch:98   - Cost:1.45     Valid Accuracy: 0.737
# Epoch:99   - Cost:1.45     Valid Accuracy: 0.739
# Test Accuracy:0.7437000274658203
